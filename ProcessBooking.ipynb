# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Install Packages

# %%
# !pip install hampel
# !pip install pwlf
# !pip install EMD-signal
# Out:
# Collecting hampel
#   Downloading hampel-1.0.2.tar.gz (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 2.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.11/dist-packages (from hampel) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from hampel) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->hampel) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->hampel) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->hampel) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->hampel) (1.17.0)
# Building wheels for collected packages: hampel
#   Building wheel for hampel (pyproject.toml) ... done
#   Created wheel for hampel: filename=hampel-1.0.2-cp311-cp311-linux_x86_64.whl size=219572 sha256=3a646d7d2fb2abc87b14b860a6503505919ebe4f8d969d441fce1a1e698dbc41
#   Stored in directory: /root/.cache/pip/wheels/fd/e9/7e/ad82a52cf81975fce3dd6ae0e00bf26787b546e2518ad861d4
# Successfully built hampel
# Installing collected packages: hampel
# Successfully installed hampel-1.0.2
# Collecting pwlf
#   Downloading pwlf-2.5.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from pwlf) (2.0.2)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from pwlf) (1.14.1)
# Downloading pwlf-2.5.1-py3-none-any.whl (17 kB)
# Installing collected packages: pwlf
# Successfully installed pwlf-2.5.1
# Collecting EMD-signal
#   Downloading EMD_signal-1.6.4-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.11/dist-packages (from EMD-signal) (2.0.2)
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.11/dist-packages (from EMD-signal) (1.14.1)
# Collecting pathos>=0.2.1 (from EMD-signal)
#   Downloading pathos-0.3.4-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: tqdm<5.0,>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from EMD-signal) (4.67.1)
# Collecting ppft>=1.7.7 (from pathos>=0.2.1->EMD-signal)
#   Downloading ppft-1.7.7-py3-none-any.whl.metadata (12 kB)
# Collecting dill>=0.4.0 (from pathos>=0.2.1->EMD-signal)
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting pox>=0.3.6 (from pathos>=0.2.1->EMD-signal)
#   Downloading pox-0.3.6-py3-none-any.whl.metadata (8.0 kB)
# Collecting multiprocess>=0.70.18 (from pathos>=0.2.1->EMD-signal)
#   Downloading multiprocess-0.70.18-py311-none-any.whl.metadata (7.5 kB)
# Downloading EMD_signal-1.6.4-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.9 MB/s eta 0:00:00
# Downloading pathos-0.3.4-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.3/82.3 kB 6.4 MB/s eta 0:00:00
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 9.6 MB/s eta 0:00:00
# Downloading multiprocess-0.70.18-py311-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 11.8 MB/s eta 0:00:00
# Downloading pox-0.3.6-py3-none-any.whl (29 kB)
# Downloading ppft-1.7.7-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: ppft, pox, dill, multiprocess, pathos, EMD-signal
# Successfully installed EMD-signal-1.6.4 dill-0.4.0 multiprocess-0.70.18 pathos-0.3.4 pox-0.3.6 ppft-1.7.7

# %% [markdown]
# ## Import Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import SimpleExpSmoothing, Holt, ExponentialSmoothing
import scipy
from PyEMD import EEMD

from sklearn.metrics import mean_squared_error
from operator import add

from hampel import hampel
import pwlf
from statsmodels.sandbox.stats.runs import runstest_1samp

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Sine Regression

# %%
def fit_sin(tt, yy):
    '''Fit sin to the input time sequence, and return fitting parameters "amp", "omega", "phase", "offset", "freq", "period" and "fitfunc"'''
    tt = np.array(tt)
    yy = np.array(yy)
    ff = np.fft.fftfreq(len(tt), (tt[1]-tt[0]))   # assume uniform spacing
    Fyy = abs(np.fft.fft(yy))
    guess_freq = abs(ff[np.argmax(Fyy[1:])+1])   # excluding the zero frequency "peak", which is related to offset
    guess_amp = np.std(yy) * 2.**0.5
    guess_offset = np.mean(yy)
    guess = np.array([guess_amp, 2.*np.pi*guess_freq, 0., guess_offset])

    def sinfunc(t, A, w, p, c):  return A * np.sin(w*t + p) + c
    popt, pcov = scipy.optimize.curve_fit(sinfunc, tt, yy, p0=guess)
    A, w, p, c = popt
    f = w/(2.*np.pi)
    fitfunc = lambda t: A * np.sin(w*t + p) + c
    return {"amp": A, "omega": w, "phase": p, "offset": c, "freq": f, "period": 1./f, "fitfunc": fitfunc, "maxcov": np.max(pcov), "rawres": (guess,popt,pcov)}

def fit_sin_fixed_period(tt, yy, fixed_period, amp=None):
    '''Fit a sine wave with a fixed period to the input time sequence.'''
    tt = np.array(tt)
    yy = np.array(yy)

    # Calculate fixed angular frequency
    fixed_omega = 2. * np.pi / fixed_period

    # Define sine function with fixed angular frequency
    def sinfunc(t, A, p, c):
        return A * np.sin(fixed_omega * t + p) + c

    # Make initial guesses for amplitude, phase, and offset
    if amp is None:
      guess_amp = np.std(yy) * (2.**0.5)
    else:
      guess_amp = amp
    guess_phase = 0
    guess_offset = np.mean(yy)
    guess = [guess_amp, guess_phase, guess_offset]

    # Perform curve fitting
    popt, pcov = scipy.optimize.curve_fit(sinfunc, tt, yy, p0=guess)
    A, p, c = popt

    # Define the fitting function
    fitfunc = lambda t: A * np.sin(fixed_omega * t + p) + c

    return {
        "amp": A,
        "omega": fixed_omega,
        "phase": p,
        "offset": c,
        "period": fixed_period,
        "fitfunc": fitfunc,
        "maxcov": np.max(pcov),
        "rawres": (guess, popt, pcov)
    }

# %% [markdown]
# ### Generate x ticks labels

# %%
# generate x ticks labels with dates
def x_ticks_labels(data, skip_days):
  #skip_days = 0 # do not skip any data. We may skip first 26 days which has only 1 trails per day

  # generate date based labels for x ticks
  xticks = range(0,350,25) # 0 to 350, 14 ticks
  xticks_labels = [' '] * len(xticks)
  for i in range(len(xticks)):
    xticks_labels[i] = str(xticks[i]) + ": " + data['Date'][xticks[i]+skip_days]
  return xticks, xticks_labels

# %% [markdown]
# ### Error Calculation

# %%
def calculate_mape(actual, predicted):
    # Convert actual and predicted
    # to numpy array data type if not already
    if not all([isinstance(actual, np.ndarray),
                isinstance(predicted, np.ndarray)]):
        actual, predicted = np.array(actual), np.array(predicted)

    # Calculate the MAPE value and return
    return round(np.mean(np.abs((
      actual - predicted) / actual)) * 100, 2)

# %% [markdown]
# ### Randomness Test

# %%
def is_data_random(data):
  #Perform Runs test, runtest_1samp from statsmodels.sandbox.stats.runs
  result = runstest_1samp(data, correction=False)

  print(f"p-value: {result[-1]:.5f}")

  if result[-1] < 0.01:
    print("The null hypothesis can be rejected: Not Random")
    return False
  else:
    print("The null hypothesis cannot be rejected: Random")
    return True

# %% [markdown]
# ## Download Data CSV Files

# %%
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1VF5WvQ9HMXR6RVdMr9VXRxkpIX_rcFyk' -O daily_means.csv
# Out:
# --2025-04-27 22:04:02--  https://docs.google.com/uc?export=download&id=1VF5WvQ9HMXR6RVdMr9VXRxkpIX_rcFyk
# Resolving docs.google.com (docs.google.com)... 74.125.69.139, 74.125.69.102, 74.125.69.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.69.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1VF5WvQ9HMXR6RVdMr9VXRxkpIX_rcFyk&export=download [following]
# --2025-04-27 22:04:02--  https://drive.usercontent.google.com/download?id=1VF5WvQ9HMXR6RVdMr9VXRxkpIX_rcFyk&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 64.233.179.132, 2607:f8b0:4001:c68::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|64.233.179.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70896 (69K) [application/octet-stream]
# Saving to: ‘daily_means.csv’
#
# daily_means.csv     100%[===================>]  69.23K  --.-KB/s    in 0.001s
#
# 2025-04-27 22:04:04 (88.6 MB/s) - ‘daily_means.csv’ saved [70896/70896]

# %% [markdown]
# ## Load and Plot Original Means

# %%
data = pd.read_csv('daily_means.csv')

# %%
skip_days = 0 # do not skip any data. We may skip first 26 days which has only 1 trails per day
xticks, xticks_labels = x_ticks_labels(data, skip_days)
original_means = data['ProcessBooking'][skip_days:].reset_index(drop=True)
ax = original_means.plot(xlabel="Days", ylabel="Latency (us)", title="Original Means", figsize=(12,4))
ax.set_xticks(xticks, xticks_labels, rotation=270)
ax.xaxis.grid(True, which='major')
ax.yaxis.grid(True, which='major')
plt.show()

# %%
outlier_filtered = hampel(data['ProcessBooking'], window_size=24)

# %%
data['cleaned_ProcessBooking'] = outlier_filtered.filtered_data
skip_days = 0 # do not skip any data. We may skip first 26 days which has only 1 trails per day
xticks, xticks_labels = x_ticks_labels(data, skip_days)
cleaned_means = data['cleaned_ProcessBooking'][skip_days:].reset_index(drop=True)
ax = cleaned_means.plot(xlabel="Days", ylabel="Latency (us)", title="Outlier filtered Means", figsize=(12,4))
ax.set_xticks(xticks, xticks_labels, rotation=270)
ax.xaxis.grid(True, which='major')
ax.yaxis.grid(True, which='major')
plt.show()

# %% [markdown]
# # Hybrid Analysis

# %%
original_means = data['ProcessBooking'][skip_days:].reset_index(drop=True)
cleaned_means_for_manu = data['cleaned_ProcessBooking'][skip_days:].reset_index(drop=True)

train_size = 301
test_size = len(original_means) - train_size


train_means_manu = cleaned_means_for_manu[:train_size]
test_means_manu = cleaned_means_for_manu[train_size:]

# %% [markdown]
# ## Linear Regression

# %%
plr = train_means_manu.reset_index()
plr.columns = ['index_column', 'value_column']

myPWLF = pwlf.PiecewiseLinFit(plr['index_column'], plr['value_column'])

z = myPWLF.fit(2)
slopes = myPWLF.calc_slopes()
xHat = plr['index_column']
insample_predictions = myPWLF.predict(xHat)

test_indices = range(train_size, len(original_means))
test_predictions = myPWLF.predict(test_indices)

# %%
linear_predictions = np.concatenate([insample_predictions, test_predictions])
linear_residuals = cleaned_means_for_manu - linear_predictions

# %%
ax = cleaned_means_for_manu.plot(xlabel="Days", ylabel="Latency (us)", title="Original Means vs Piecewise Linear Fit",
                         figsize=(12,4), label="Original Means")
ax.plot(xHat, insample_predictions, color='green', linewidth=2, label="Piecewise Linear Fit Insample Predictions")
ax.plot(test_indices, test_predictions, color='red', linewidth=2, label="Piecewise Linear Fit Test predictions")
ax.set_xticks(xticks, xticks_labels, rotation=270)
ax.legend()
ax.set_xlabel("Days")
ax.set_ylabel("Latency (ms)")
ax.xaxis.grid(True, which='major')
ax.yaxis.grid(True, which='major')
plt.show()

# %% [markdown]
# ## Seasonal Variation

# %%
train_linear_residuals = linear_residuals[:train_size]
test_linear_residuals = linear_residuals[train_size:]

# %%
x_idx_train = np.array([float(i) for i in range(train_size)])
sin_curve = fit_sin(x_idx_train, train_linear_residuals)
# Out:
# <ipython-input-3-ded72c2a4ac3>:13: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = scipy.optimize.curve_fit(sinfunc, tt, yy, p0=guess)

# %%
x_idx_full = np.array([float(i) for i in range(len(original_means))])
sine_predictions = sin_curve["fitfunc"](np.array(x_idx_full))
sine_residuals = linear_residuals - sine_predictions

# %%
ax = linear_residuals.plot(label="Residuals after Linear Fit", figsize=(12,4))
ax.plot(sine_predictions[:train_size],label="Sine Fitted Residuals (in-sample)")
ax.plot(range(train_size, train_size+test_size, 1), sine_predictions[train_size:],label="Sine Fitted Residuals (out-sample)")
ax.set_title("Linear Residuals Fitted with Sine")
ax.set_xlabel("Days")
ax.set_ylabel("Latency (us)")
ax.legend()
plt.show()

# %% [markdown]
# ## Monthly Variation

# %% [markdown]
# ### First Monthly Regression

# %%
train_1st_monthly = sine_residuals[:train_size]
test_1st_montly = sine_residuals[train_size:]

# %%
seg1_start = 0
seg1_end = 125

x_idx_train_1st_monthly_seg1 = np.array([float(i) for i in range(seg1_start,seg1_end,1)])
sin_curve_1st_montly_seg1 = fit_sin(x_idx_train_1st_monthly_seg1, train_1st_monthly[seg1_start:seg1_end])

# %%
x_idx_full_1st_monthly_seg1 = np.array([float(i) for i in range(seg1_start,seg1_end,1)])
sine_predictions_1st_monthly_seg1 = sin_curve_1st_montly_seg1["fitfunc"](np.array(x_idx_full_1st_monthly_seg1))

# %%
seg2_start = seg1_end
seg2_end = 205

x_idx_train_1st_monthly_seg2 = np.array([float(i) for i in range(seg2_start,seg2_end,1)])
sin_curve_1st_montly_seg2 = fit_sin(x_idx_train_1st_monthly_seg2, train_1st_monthly[seg2_start:seg2_end])

# %%
x_idx_full_1st_monthly_seg2 = np.array([float(i) for i in range(seg2_start,seg2_end,1)])
sine_predictions_1st_monthly_seg2 = sin_curve_1st_montly_seg2["fitfunc"](np.array(x_idx_full_1st_monthly_seg2))

# %%
seg3_start = seg2_end
seg3_end = 301

x_idx_train_1st_monthly_seg3 = np.array([float(i) for i in range(seg3_start,seg3_end,1)])
sin_curve_1st_montly_seg3 = fit_sin_fixed_period(x_idx_train_1st_monthly_seg3, train_1st_monthly[seg3_start:seg3_end], 27)

# %%
x_idx_full_1st_monthly_seg3 = np.array([float(i) for i in range(seg3_start,329,1)])
sine_predictions_1st_monthly_seg3 = sin_curve_1st_montly_seg3["fitfunc"](np.array(x_idx_full_1st_monthly_seg3))

# %%
sine_predictions_1st_monthly_segments = np.append(sine_predictions_1st_monthly_seg1,
                                         sine_predictions_1st_monthly_seg2)
sine_predictions_1st_monthly_segments = np.append(sine_predictions_1st_monthly_segments,
                                                  sine_predictions_1st_monthly_seg3)
sine_residuals_1st_monthly_segments = sine_residuals - sine_predictions_1st_monthly_segments

# %%
# put three segments together
sine_predictions_1st_monthly_segments = np.append(sine_predictions_1st_monthly_seg1,
                                         sine_predictions_1st_monthly_seg2)
sine_predictions_1st_monthly_segments = np.append(sine_predictions_1st_monthly_segments,
                                                  sine_predictions_1st_monthly_seg3)
ax = sine_residuals.plot(label="Residuals after Seasonal Sine Fit", figsize=(12,4))
ax.plot(sine_predictions_1st_monthly_segments,label="1st Monthly Fitted")
ax.set_title("1st Monthly Fit with Sine (Segment1)")
ax.set_xlabel("Days")
ax.set_ylabel("Latency (us)")
ax.legend()
plt.show()

# %% [markdown]
# ### Second Monthly Regression

# %%
train_2nd_monthly_after_seg = sine_residuals_1st_monthly_segments[:train_size]
test_2nd_montly_after_seg = sine_residuals_1st_monthly_segments[train_size:]

# %%
x_idx_train_2nd_monthly_after_seg = np.array([float(i) for i in range(train_size)])
sin_curve_2nd_montly_after_seg = fit_sin_fixed_period(x_idx_train_2nd_monthly_after_seg, train_2nd_monthly_after_seg, 14.3)

# %%
x_idx_full_2nd_monthly_after_seg = np.array([float(i) for i in range(len(original_means))])
sine_predictions_2nd_monthly_after_seg = sin_curve_2nd_montly_after_seg["fitfunc"](np.array(x_idx_full_2nd_monthly_after_seg))
sine_residuals_2nd_monthly_after_seg = sine_residuals_1st_monthly_segments - sine_predictions_2nd_monthly_after_seg

# %%
ax = sine_residuals_1st_monthly_segments.plot(label="Residuals after 1st Monthly Regression", figsize=(12,4))
ax.plot(sine_predictions_2nd_monthly_after_seg[:train_size],label="2nd Monthly Fitted")
ax.plot(range(train_size, train_size+test_size, 1), sine_predictions_2nd_monthly_after_seg[train_size:],label="1st Monthly Fitted (out-sample)")
ax.set_title("2nd Monthly Fit with Sine")
ax.set_xlabel("Days")
ax.set_ylabel("Latency (us)")
ax.legend()
plt.show()

# %% [markdown]
# ## Daily HWES

# %% [markdown]
# ### First HWES

# %%
train_1st_hwes = sine_residuals_2nd_monthly_after_seg[:train_size]
test_1st_hwes = sine_residuals_2nd_monthly_after_seg[train_size:]

# %%
fitted_model = ExponentialSmoothing(train_1st_hwes,trend='add', seasonal='add', seasonal_periods=24).fit(smoothing_level=0.2, smoothing_trend=0.1, smoothing_seasonal=0.4, optimized=False)
test_predictions = fitted_model.forecast(28)
insample_predictions = fitted_model.predict(0)

# %%
sine_residuals_2nd_monthly_after_seg.plot(legend=True,label='Daily Fluctuation',figsize=(12,4))
insample_predictions.plot(legend=True,label='Daily Fluctuation Prediction (insample)')
test_predictions.plot(legend=True,label='Daily Fluctuation Prediction (outsample)')
plt.title('HWES Train, Test and Predicted')
# Out:
# Text(0.5, 1.0, 'HWES Train, Test and Predicted')

# %% [markdown]
# #### Randomnes Test

# %%
first_hwes_predictions = np.append(insample_predictions.to_numpy(), test_predictions.to_numpy())
first_hwes_residuals = sine_residuals_2nd_monthly_after_seg - first_hwes_predictions
is_random = is_data_random(first_hwes_residuals)
print("is random after first hwes:", is_random)
# Out:
# p-value: 0.00000
# The null hypothesis can be rejected: Not Random
# is random after first hwes: False

# %% [markdown]
# ### Second HWES

# %%
train_2nd_hwes = first_hwes_residuals[:train_size]
test_2nd_hwes = first_hwes_residuals[train_size:]

# %%
fitted_model_2nd_hwes = ExponentialSmoothing(train_2nd_hwes, trend='add', seasonal='add', seasonal_periods=21).fit(smoothing_level=0.4, smoothing_trend=0.2, smoothing_seasonal=0.4, optimized=False)
test_predictions_2nd_hwes = fitted_model_2nd_hwes.forecast(28)
insample_predictions_2nd_hwes = fitted_model_2nd_hwes.predict(0)

# %%
first_hwes_residuals.plot(legend=True,label='Daily Fluctuation',figsize=(12,4))
insample_predictions_2nd_hwes.plot(legend=True,label='Daily Fluctuation Prediction (insample)')
test_predictions_2nd_hwes.plot(legend=True,label='Daily Fluctuation Prediction (outsample)')
plt.title('HWES Train, Test and Predicted')
# Out:
# Text(0.5, 1.0, 'HWES Train, Test and Predicted')

# %% [markdown]
# #### Randomness Test

# %%
second_hwes_predictions = np.append(insample_predictions_2nd_hwes.to_numpy(), test_predictions_2nd_hwes.to_numpy())
second_hwes_residuals = first_hwes_residuals - second_hwes_predictions
is_random = is_data_random(second_hwes_residuals)
print("is random after first hwes:", is_random)
# Out:
# p-value: 0.29595
# The null hypothesis cannot be rejected: Random
# is random after first hwes: True

# %% [markdown]
# ## Combine Predictions

# %%
monthly_predictions = list(map(add, sine_predictions_1st_monthly_segments, sine_predictions_2nd_monthly_after_seg))
hwes_predictions = list(map(add, first_hwes_predictions, second_hwes_predictions))

# %%
manual_predictions = list(map(add, linear_predictions, sine_predictions))
manual_predictions = list(map(add, manual_predictions, monthly_predictions))
manual_predictions = list(map(add, manual_predictions, hwes_predictions))

# %%
ax = original_means.plot(label="Original Means", figsize=(12,4))
ax.plot(manual_predictions[0:train_size], label="Insample Predictions")
ax.plot(range(train_size, len(original_means),1),
        manual_predictions[train_size:], label="Outsample Predictions")
ax.legend()
ax.set_title("ProcessBooking Hybrid Prediction")
ax.set_xlabel("Days")
ax.set_ylabel("Latency (us)")
plt.show()

# %%
ax = original_means[train_size:].plot(label="Original Means", figsize=(12,4))
ax.plot(range(train_size, len(original_means),1),
        manual_predictions[train_size:], label="Outsample Predictions")
ax.legend()
ax.set_title("ProcessBooking Hybrid Prediction: Test Part zoomed in view")
ax.set_xlabel("Days")
ax.set_ylabel("Latency (us)")
plt.show()

# %%
hwes_mape = calculate_mape(original_means[301:], manual_predictions[train_size:])
print('MAPE of predition using HWES:', hwes_mape)
# Out:
# MAPE of predition using HWES: 1.52

# %% [markdown]
# # Automatic Analysis

# %%
cleaned_means_for_eemd = data['cleaned_ProcessBooking'][skip_days:].reset_index(drop=True)
train_original_means = cleaned_means_for_eemd[:301]

sample_rate = 0.00001157

# %%
eemd = EEMD()
eemd(train_original_means.to_numpy())
eimfs, eres = eemd.get_imfs_and_residue()

# %%
# plot the IMFs
for i in range(eimfs.shape[0]):
    plt.figure(figsize=(20,3))
    plt.plot(eimfs[i], 'k')
    plt.title(f"IMF{i+1}")
    plt.xlabel("Days")
    plt.ylabel("latency (ms)")
    plt.xticks(np.arange(0, 302, step=7))
    plt.grid(visible=True)
    plt.locator_params(axis='y', nbins=5)
    plt.show()
# plot the residue
plt.figure(figsize=(20,3))
plt.plot(eres, 'g')
plt.title("EEMD Residue")
plt.xlabel("Days")
plt.ylabel("latency (ms)")
plt.locator_params(axis='y', nbins=5)
plt.show()

# %%
eimfs = eimfs.transpose()

# %% [markdown]
# ### Forecasting

# %% [markdown]
# #### HWES

# %% [markdown]
# ##### IMF-1

# %%
imf_1 = eimfs[:301, 0]
imf_1 = pd.Series(imf_1)
train_data = imf_1[0:301]

# %%
fitted_model = ExponentialSmoothing(train_data,trend='add', seasonal='add', seasonal_periods=21).fit(smoothing_level=0.2, smoothing_trend=0.2, smoothing_seasonal=0.8)
test_predictions = fitted_model.forecast(28)
insample_predictions = fitted_model.predict(0)

# %%
train_data.plot(legend=True,label='TRAIN', figsize=(12,5))
test_predictions.plot(legend=True,label='PREDICTION')
plt.title('IMF-1 prediction using HWES')
# Out:
# Text(0.5, 1.0, 'IMF-1 prediction using HWES')

# %%
index = range(329)
predicted_imf_1 = pd.Series(index=index)
predicted_imf_1[0:301] = insample_predictions
predicted_imf_1[301:329] = test_predictions

# %% [markdown]
# ##### IMF-2

# %%
imf_2 = eimfs[:301, 1]
imf_2 = pd.Series(imf_2)
train_data = imf_2[0:301]

# %%
fitted_model = ExponentialSmoothing(train_data, seasonal='add',seasonal_periods=10).fit(smoothing_level=0.2, smoothing_trend=0.8, smoothing_seasonal=0.8)
test_predictions = fitted_model.forecast(28)
insample_predictions = fitted_model.predict(0)

# %%
train_data.plot(legend=True,label='TRAIN', figsize=(12,5))
test_predictions.plot(legend=True,label='PREDICTION')
plt.title('IMF-2 prediction using HWES')
# Out:
# Text(0.5, 1.0, 'IMF-2 prediction using HWES')

# %%
predicted_imf_2 = pd.Series(index=index)
predicted_imf_2[0:301] = insample_predictions
predicted_imf_2[301:329] = test_predictions

# %% [markdown]
# ##### IMF-3

# %%
imf_3 = eimfs[:301, 2]
imf_3 = pd.Series(imf_3)
train_data = imf_3[0:301]

# %%
fitted_model = ExponentialSmoothing(train_data, trend='add', seasonal='add',seasonal_periods=21).fit(smoothing_level=0.2)
test_predictions = fitted_model.forecast(28)
insample_predictions = fitted_model.predict(0)

# %%
train_data.plot(legend=True,label='TRAIN', figsize=(12,5))
test_predictions.plot(legend=True,label='PREDICTION')
plt.title('IMF-3 prediction using HWES')
# Out:
# Text(0.5, 1.0, 'IMF-3 prediction using HWES')

# %%
predicted_imf_3 = pd.Series(index=index)
predicted_imf_3[0:301] = insample_predictions
predicted_imf_3[301:329] = test_predictions

# %% [markdown]
# ##### IMF-4

# %%
imf_4 = eimfs[:301, 3]
imf_4 = pd.Series(imf_4)
train_data = imf_4[0:301]

# %%
fitted_model = ExponentialSmoothing(train_data,trend='add', seasonal='add', seasonal_periods=28).fit(smoothing_level=0.2, smoothing_trend=0.8, smoothing_seasonal=0.8)
test_predictions = fitted_model.forecast(28)
insample_predictions = fitted_model.predict(0)

# %%
train_data.plot(legend=True,label='TRAIN', figsize=(12,5))
test_predictions.plot(legend=True,label='PREDICTION')
plt.title('IMF-4 prediction using HWES')
# Out:
# Text(0.5, 1.0, 'IMF-4 prediction using HWES')

# %%
predicted_imf_4 = pd.Series(index=index)
predicted_imf_4[0:301] = insample_predictions
predicted_imf_4[301:329] = test_predictions

# %% [markdown]
# ##### IMF-5

# %%
imf_5 = eimfs[:301, 4]
imf_5 = pd.Series(imf_5)
train_data = imf_5[0:301]

# %%
fitted_model = ExponentialSmoothing(train_data,trend='add',seasonal='add', seasonal_periods=150).fit(smoothing_level=0.2, smoothing_trend=0.8, smoothing_seasonal=0.8)
test_predictions = fitted_model.forecast(28)
insample_predictions = fitted_model.predict(0)

# %%
train_data.plot(legend=True,label='TRAIN', figsize=(12,5))
test_predictions.plot(legend=True,label='PREDICTION')
plt.title('IMF-5 prediction using HWES')
# Out:
# Text(0.5, 1.0, 'IMF-5 prediction using HWES')

# %%
predicted_imf_5 = pd.Series(index=index)
predicted_imf_5[0:301] = insample_predictions
predicted_imf_5[301:329] = test_predictions

# %% [markdown]
# ##### Residual

# %%
summed_imf = eimfs[:301, 0] + eimfs[:301, 1] + eimfs[:301, 2] + eimfs[:301, 3] + eimfs[:301, 4]
residual = train_original_means - summed_imf

residual = pd.Series(residual)
train_data = residual[0:301]

# %%
fitted_model = ExponentialSmoothing(train_data,trend='add',seasonal='add',seasonal_periods=7).fit()
test_predictions = fitted_model.forecast(28)
insample_predictions = fitted_model.predict(0)

# %%
train_data.plot(legend=True,label='TRAIN', figsize=(12,5))
test_predictions.plot(legend=True,label='PREDICTION')
plt.title('Residual prediction using HWES')
# Out:
# Text(0.5, 1.0, 'Residual prediction using HWES')

# %%
predicted_residual = pd.Series(index=index)
predicted_residual[0:301] = insample_predictions
predicted_residual[301:329] = test_predictions

# %% [markdown]
# ##### Predicted Signal

# %%
eemd_predicted_signal = predicted_imf_1 + predicted_imf_2 + predicted_imf_3 + predicted_imf_4 + predicted_imf_5 + predicted_residual

# %%
ax = original_means.plot(label="Original Means", figsize=(12,4))
ax.plot(eemd_predicted_signal[0:train_size], label="Insample Predictions")
ax.plot(range(train_size, len(original_means),1),
        eemd_predicted_signal[train_size:], label="Outsample Predictions")
ax.legend()
ax.set_title("ProcessBooking Automatic Prediction")
ax.set_xlabel("Days")
ax.set_ylabel("Latency (us)")
plt.show()

# %%
ax = original_means[train_size:].plot(label="Original Means", figsize=(12,4))
ax.plot(range(train_size, len(original_means),1),
        eemd_predicted_signal[train_size:], label="Outsample Predictions")
ax.legend()
ax.set_title("ProcessBooking Automatic Prediction: Test Part zoomed in view")
ax.set_xlabel("Days")
ax.set_ylabel("Latency (us)")
plt.show()

# %%
hwes_mape = calculate_mape(original_means[301:], eemd_predicted_signal[301:])
print('MAPE of predition using HWES: ', hwes_mape)
# Out:
# MAPE of predition using HWES:  1.19
